# %%
import os
import xarray as xr
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

import time

# %% [markdown]
# # Some constants:

# %%
data_dir = '/home/hawbecker/kaggle/LEAP'

frame_size = 384 # From the test file
total_len = 625000 # size of training set
train_size = 400000 # amount of data from training set we use for training
test_size = total_len - train_size
batch_size = frame_size * 10

train_data_file = os.path.join(data_dir,'train.csv')
test_data_file = os.path.join(data_dir,'test.csv')
submission_file = os.path.join(data_dir,'sample_submission.csv')

# %% [markdown]
# # Load in the data:

# %%
#### Sample data:
sample_ds = xr.open_dataset(os.path.join(data_dir,'ClimSim_low-res_grid-info.nc'))

lat = sample_ds.lat
lon = sample_ds.lon
ak = sample_ds.hyam
bk = sample_ds.hybm
stride = len(lat)

# %%
# Sample 100 rows of data to determine dtypes.
df_test = pd.read_csv(train_data_file, nrows=100)

float_cols = [c for c in df_test if df_test[c].dtype == "float64"]
float32_cols = {c: np.float32 for c in float_cols}

# %% [markdown]
# # Get the 2D and 3D variable names:

# %%
# Get 2d / 3d variables:
with open(train_data_file,'r') as f:
    header = f.readline().split(',')

Xvars_2d = []
Xvars_3d = []

Yvars_2d = []
Yvars_3d = []

for col in header[1:]:
    col = col.replace('\n','')
    col = col.split('_')
    if (len(col) == 3) & (col[-1].isnumeric()): # 3-D
        if col[0] == 'ptend': # Targets
            Yvars_3d += ['_'.join(col[:2])]
        else: # Features
            Xvars_3d += ['_'.join(col[:2])]
    else: # 2-D
        if col[1] == 'out': # Targets:
            Yvars_2d += ['_'.join(col)]
        else: # Features
            Xvars_2d += ['_'.join(col)]
Xvars_3d = list(np.unique(Xvars_3d))
Yvars_3d = list(np.unique(Yvars_3d))
print(Xvars_3d)
print(Yvars_3d)
# Out:
# ['pbuf_CH4', 'pbuf_N2O', 'pbuf_ozone', 'state_q0001', 'state_q0002', 'state_q0003', 'state_t', 'state_u', 'state_v']
# ['ptend_q0001', 'ptend_q0002', 'ptend_q0003', 'ptend_t', 'ptend_u', 'ptend_v']

# %%
print(Xvars_2d)
print(Yvars_2d)
# Out:
# ['state_ps', 'pbuf_SOLIN', 'pbuf_LHFLX', 'pbuf_SHFLX', 'pbuf_TAUX', 'pbuf_TAUY', 'pbuf_COSZRS', 'cam_in_ALDIF', 'cam_in_ALDIR', 'cam_in_ASDIF', 'cam_in_ASDIR', 'cam_in_LWUP', 'cam_in_ICEFRAC', 'cam_in_LANDFRAC', 'cam_in_OCNFRAC', 'cam_in_SNOWHLAND']
# ['cam_out_NETSW', 'cam_out_FLWDS', 'cam_out_PRECSC', 'cam_out_PRECC', 'cam_out_SOLS', 'cam_out_SOLL', 'cam_out_SOLSD', 'cam_out_SOLLD']

# %%
vars_3d = Xvars_3d + Yvars_3d
vars_2d = Xvars_2d + Yvars_2d

# %% [markdown]
# # Convert the data to columns:

# %%
def get_point(point_df,point_count,x_or_y=None):
    p0 = 100000
    p_levels = 60
    plvls = []
    for pp in range(p_levels):
        plvl = float(ak[pp])*p0 + float(bk[pp])*point_df.state_ps
        point_df['state_p_{}'.format(pp)] = plvl
    print(point_df['state_P_0'])
    wefwef
    empty3d = np.zeros([p_levels])

    # 3-D Variables:
    init_df = True
    
    for varn in (vars_3d + ['state_p_']):
        data = empty3d.copy()
        for col in point_df.columns:
            if varn in col:
                data_lvl = point_df[col]
                lvl = int(col.split('_')[-1])
                data[lvl] = data_lvl.values
        data_da = xr.DataArray(data=data,name=varn,dims={'level':np.arange(0,p_levels)})
        if init_df:
            data_ds = data_da
            init_df = False
        else:
            data_ds = xr.merge([data_ds,data_da])

    # 2-D Variables:
    for col in vars_2d:
        #data = point_df[col].values
        # Fill 2-D data so it looks 3D for convolution:
        if col in point_df.columns:
            data = np.ones(np.shape(empty3d))*point_df[col].values
            data_da = xr.DataArray(data=data,name=col,dims={'level':np.arange(0,p_levels)})
            #data_da = xr.DataArray(data=data,name=col,dims={'point':np.arange(0,point_size)})
            data_ds = xr.merge([data_ds,data_da])

    data_ds = data_ds.expand_dims({'point':[point_count]})
    if x_or_y == 'x':
        data_ds = data_ds[Xvars_3d + Xvars_2d]
    else:
        data_ds = data_ds[Yvars_3d + Yvars_2d]
        
    return(data_ds)

# %%
def process_data(df,get_y=True,save_dir='./',batch_num=None):

    for ll,loc in enumerate(df.index):
        point_df = pd.DataFrame(df.loc[loc]).T
        if ll == 0:
            X_ds = get_point(point_df,loc,x_or_y='x')
            if get_y:
                Y_ds = get_point(point_df,loc,x_or_y='y')
        else:
            X_ds = xr.merge([X_ds,get_point(point_df,loc,x_or_y='x')])
            if get_y:
                Y_ds = xr.merge([Y_ds,get_point(point_df,loc,x_or_y='y')])

    if get_y:
        file_name = os.path.join(save_dir,'train_data_')
        X_ds.to_netcdf(file_name + 'X_{0:04d}.nc'.format(batch_num))
        Y_ds.to_netcdf(file_name + 'Y_{0:04d}.nc'.format(batch_num))
    else:
        file_name = os.path.join(save_dir,'test_data_')
        X_ds.to_netcdf(file_name + 'X_{0:04d}.nc'.format(batch_num))
                
    if get_y:
        return(X_ds,Y_ds)
    else:
        return(X_ds)

# %% [markdown]
# # Process the data:

# %% [markdown]
# ### Train data:

# %%
max_locs = 5000
for ss,skip_rows in enumerate(range(0,total_len,max_locs)):
    got_xy = [False,False]
    for dd,dim in enumerate(['X','Y']):
        save_dir = os.path.join(data_dir,'processed_data')
        file_name = os.path.join(save_dir,'train_data_{0}_{1:04d}.nc'.format(dim,ss))
        if os.path.exists(file_name):
            got_xy[dd] = True
    if not np.all(got_xy):
        print('Loading data batch: {}/{}'.format(ss+1,int(total_len/max_locs)))
        load_s = time.time()
        train_df = pd.read_csv(train_data_file, engine='c', 
                               header=0,
                               dtype=float32_cols, 
                               nrows=max_locs,
                               skiprows=range(1,skip_rows+1))
        train_df.index += skip_rows
        load_e = time.time()
        load_time = load_e - load_s
        print('\t\tLoaded in {}s.\n\t\tStart processing...'.format(load_time))
        train_df = train_df[train_df.columns[1:]]
        last_X,last_Y = process_data(train_df,
                                     save_dir=os.path.join(data_dir,'processed_data'),
                                     batch_num=ss)
        proc_e = time.time()
        proc_time = proc_e - load_e
        print('\t\tProcessed in {}s'.format(proc_time))
    print('{} already generated'.format(file_name))
# Out:
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0000.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0001.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0002.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0003.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0004.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0005.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0006.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0007.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0008.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0009.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0010.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0011.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0012.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0013.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0014.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0015.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0016.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0017.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0018.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0019.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0020.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0021.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0022.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0023.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0024.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0025.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0026.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0027.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0028.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0029.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0030.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0031.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0032.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0033.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0034.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0035.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0036.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0037.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0038.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0039.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0040.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0041.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0042.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0043.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0044.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0045.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0046.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0047.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0048.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0049.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0050.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0051.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0052.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0053.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0054.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0055.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0056.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0057.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0058.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0059.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0060.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0061.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0062.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0063.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0064.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0065.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0066.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0067.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0068.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0069.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0070.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0071.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0072.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0073.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0074.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0075.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0076.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0077.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0078.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0079.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0080.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0081.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0082.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0083.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0084.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0085.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0086.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0087.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0088.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0089.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0090.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0091.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0092.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0093.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0094.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0095.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0096.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0097.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0098.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0099.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0100.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0101.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0102.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0103.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0104.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0105.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0106.nc already generated
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0107.nc already generated
# Loading data batch: 109/125
# 		Loaded in 21.686595916748047s.
# 		Start processing...
# 		Processed in 819.4581699371338s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0108.nc already generated
# Loading data batch: 110/125
# 		Loaded in 26.792294025421143s.
# 		Start processing...
# 		Processed in 795.9261116981506s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0109.nc already generated
# Loading data batch: 111/125
# 		Loaded in 20.01966905593872s.
# 		Start processing...
# 		Processed in 792.3026604652405s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0110.nc already generated
# Loading data batch: 112/125
# 		Loaded in 21.306119918823242s.
# 		Start processing...
# 		Processed in 817.1129140853882s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0111.nc already generated
# Loading data batch: 113/125
# 		Loaded in 21.374516487121582s.
# 		Start processing...
# 		Processed in 804.1174590587616s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0112.nc already generated
# Loading data batch: 114/125
# 		Loaded in 21.320592880249023s.
# 		Start processing...
# 		Processed in 806.5773394107819s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0113.nc already generated
# Loading data batch: 115/125
# 		Loaded in 21.435505867004395s.
# 		Start processing...
# 		Processed in 801.5518972873688s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0114.nc already generated
# Loading data batch: 116/125
# 		Loaded in 21.633243560791016s.
# 		Start processing...
# 		Processed in 802.9580421447754s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0115.nc already generated
# Loading data batch: 117/125
# 		Loaded in 21.768410682678223s.
# 		Start processing...
# 		Processed in 798.9551453590393s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0116.nc already generated
# Loading data batch: 118/125
# 		Loaded in 26.868572473526s.
# 		Start processing...
# 		Processed in 795.7697386741638s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0117.nc already generated
# Loading data batch: 119/125
# 		Loaded in 22.47424054145813s.
# 		Start processing...
# 		Processed in 796.604031085968s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0118.nc already generated
# Loading data batch: 120/125
# 		Loaded in 22.86298894882202s.
# 		Start processing...
# 		Processed in 805.5149035453796s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0119.nc already generated
# Loading data batch: 121/125
# 		Loaded in 23.37076210975647s.
# 		Start processing...
# 		Processed in 794.2390608787537s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0120.nc already generated
# Loading data batch: 122/125
# 		Loaded in 22.915064334869385s.
# 		Start processing...
# 		Processed in 802.8434710502625s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0121.nc already generated
# Loading data batch: 123/125
# 		Loaded in 24.14682126045227s.
# 		Start processing...
# 		Processed in 797.8671762943268s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0122.nc already generated
# Loading data batch: 124/125
# 		Loaded in 22.35127329826355s.
# 		Start processing...
# 		Processed in 780.3704617023468s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0123.nc already generated
# Loading data batch: 125/125
# 		Loaded in 22.78428626060486s.
# 		Start processing...
# 		Processed in 782.11585688591s
# /home/hawbecker/kaggle/LEAP/processed_data/train_data_Y_0124.nc already generated

# %% [markdown]
# ### Test data

# %%
total_len_test = -1
with open(test_data_file,'r') as f:
    for line in f: total_len_test += 1

# %%
total_len_test
# Out:
# 625000

# %%
def get_point(point_df,point_count,x_or_y=None):
    p0 = 100000
    p_levels = 60
    plvls = []
    for pp in range(p_levels):
        plvl = float(ak[pp])*p0 + float(bk[pp])*point_df.state_ps
        point_df['state_p_{}'.format(pp)] = plvl

    empty3d = np.zeros([p_levels])
    # 3-D Variables:
    init_df = True
    
    for varn in (vars_3d + ['state_p_']):
        data = empty3d.copy()
        for col in point_df.columns:
            if varn in col:
                data_lvl = point_df[col]
                lvl = int(col.split('_')[-1])
                data[lvl] = data_lvl.values
        if varn[-1] == '_': varn = varn[:-1]
        data_da = xr.DataArray(data=data,name=varn,dims={'level':np.arange(0,p_levels)})
        if init_df:
            data_ds = data_da
            init_df = False
        else:
            data_ds = xr.merge([data_ds,data_da])

    # 2-D Variables:
    for col in vars_2d:
        #data = point_df[col].values
        # Fill 2-D data so it looks 3D for convolution:
        if col in point_df.columns:
            data = np.ones(np.shape(empty3d))*point_df[col].values
            data_da = xr.DataArray(data=data,name=col,dims={'level':np.arange(0,p_levels)})
            #data_da = xr.DataArray(data=data,name=col,dims={'point':np.arange(0,point_size)})
            data_ds = xr.merge([data_ds,data_da])

    data_ds = data_ds.expand_dims({'point':[point_count]})
    if x_or_y == 'x':
        data_ds = data_ds[Xvars_3d + Xvars_2d + ['state_p']]
    else:
        data_ds = data_ds[Yvars_3d + Yvars_2d]

    return(data_ds)

# %%
file_name
# Out:
# '/home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0000.nc'

# %%
max_locs = 5000
for ss,skip_rows in enumerate(range(0,total_len,max_locs)):
    got_x = [False]
    for dd,dim in enumerate(['X']):
        save_dir = os.path.join(data_dir,'processed_data')
        file_name = os.path.join(save_dir,'test_data_{0}_{1:04d}.nc'.format(dim,ss))
        if os.path.exists(file_name):
            got_x[dd] = True
    if not np.all(got_x):
        print('Loading data batch: {}/{}'.format(ss+1,int(total_len_test/max_locs)))
        load_s = time.time()
        test_df = pd.read_csv(test_data_file, engine='c', 
                               header=0,
                               dtype=float32_cols, 
                               nrows=max_locs,
                               skiprows=range(1,skip_rows+1))
        test_df.index += skip_rows
        load_e = time.time()
        load_time = load_e - load_s
        print('\t\tLoaded in {}s.\n\t\tStart processing...'.format(load_time))
        test_df = test_df[test_df.columns[1:]]
        last_X = process_data(test_df,
                              get_y=False,
                              save_dir=os.path.join(data_dir,'processed_data'),
                              batch_num=ss)
        proc_e = time.time()
        proc_time = proc_e - load_e
        print('\t\tProcessed in {}s'.format(proc_time))
    print('{} already generated'.format(file_name))
# Out:
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0000.nc already generated
# Loading data batch: 2/125
# 		Loaded in 0.43969178199768066s.
# 		Start processing...
# 		Processed in 364.28883719444275s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0001.nc already generated
# Loading data batch: 3/125
# 		Loaded in 0.5694880485534668s.
# 		Start processing...
# 		Processed in 346.95068645477295s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0002.nc already generated
# Loading data batch: 4/125
# 		Loaded in 0.7698884010314941s.
# 		Start processing...
# 		Processed in 344.6807074546814s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0003.nc already generated
# Loading data batch: 5/125
# 		Loaded in 0.7953975200653076s.
# 		Start processing...
# 		Processed in 345.64590096473694s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0004.nc already generated
# Loading data batch: 6/125
# 		Loaded in 0.9725310802459717s.
# 		Start processing...
# 		Processed in 343.4448938369751s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0005.nc already generated
# Loading data batch: 7/125
# 		Loaded in 1.0682361125946045s.
# 		Start processing...
# 		Processed in 350.35551476478577s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0006.nc already generated
# Loading data batch: 8/125
# 		Loaded in 1.3153290748596191s.
# 		Start processing...
# 		Processed in 383.28438901901245s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0007.nc already generated
# Loading data batch: 9/125
# 		Loaded in 1.446275234222412s.
# 		Start processing...
# 		Processed in 380.9575765132904s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0008.nc already generated
# Loading data batch: 10/125
# 		Loaded in 1.5334162712097168s.
# 		Start processing...
# 		Processed in 382.3658788204193s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0009.nc already generated
# Loading data batch: 11/125
# 		Loaded in 1.5357418060302734s.
# 		Start processing...
# 		Processed in 400.77964663505554s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0010.nc already generated
# Loading data batch: 12/125
# 		Loaded in 1.8505520820617676s.
# 		Start processing...
# 		Processed in 386.6170086860657s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0011.nc already generated
# Loading data batch: 13/125
# 		Loaded in 1.9428114891052246s.
# 		Start processing...
# 		Processed in 389.8137471675873s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0012.nc already generated
# Loading data batch: 14/125
# 		Loaded in 1.9645028114318848s.
# 		Start processing...
# 		Processed in 384.57605242729187s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0013.nc already generated
# Loading data batch: 15/125
# 		Loaded in 1.9997637271881104s.
# 		Start processing...
# 		Processed in 386.6425564289093s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0014.nc already generated
# Loading data batch: 16/125
# 		Loaded in 2.1399459838867188s.
# 		Start processing...
# 		Processed in 396.7661991119385s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0015.nc already generated
# Loading data batch: 17/125
# 		Loaded in 2.2852158546447754s.
# 		Start processing...
# 		Processed in 383.7366666793823s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0016.nc already generated
# Loading data batch: 18/125
# 		Loaded in 2.3715898990631104s.
# 		Start processing...
# 		Processed in 381.64903140068054s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0017.nc already generated
# Loading data batch: 19/125
# 		Loaded in 2.461059093475342s.
# 		Start processing...
# 		Processed in 382.4967701435089s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0018.nc already generated
# Loading data batch: 20/125
# 		Loaded in 2.6651477813720703s.
# 		Start processing...
# 		Processed in 386.36867928504944s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0019.nc already generated
# Loading data batch: 21/125
# 		Loaded in 2.726135015487671s.
# 		Start processing...
# 		Processed in 383.0026662349701s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0020.nc already generated
# Loading data batch: 22/125
# 		Loaded in 2.8906126022338867s.
# 		Start processing...
# 		Processed in 387.45657229423523s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0021.nc already generated
# Loading data batch: 23/125
# 		Loaded in 2.944085121154785s.
# 		Start processing...
# 		Processed in 385.20414090156555s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0022.nc already generated
# Loading data batch: 24/125
# 		Loaded in 3.1399807929992676s.
# 		Start processing...
# 		Processed in 384.2848014831543s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0023.nc already generated
# Loading data batch: 25/125
# 		Loaded in 3.2406225204467773s.
# 		Start processing...
# 		Processed in 383.1301965713501s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0024.nc already generated
# Loading data batch: 26/125
# 		Loaded in 3.5132899284362793s.
# 		Start processing...
# 		Processed in 383.0567674636841s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0025.nc already generated
# Loading data batch: 27/125
# 		Loaded in 3.5016300678253174s.
# 		Start processing...
# 		Processed in 383.62096548080444s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0026.nc already generated
# Loading data batch: 28/125
# 		Loaded in 3.693680763244629s.
# 		Start processing...
# 		Processed in 388.14104986190796s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0027.nc already generated
# Loading data batch: 29/125
# 		Loaded in 3.6960885524749756s.
# 		Start processing...
# 		Processed in 387.307035446167s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0028.nc already generated
# Loading data batch: 30/125
# 		Loaded in 3.9414150714874268s.
# 		Start processing...
# 		Processed in 385.30842995643616s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0029.nc already generated
# Loading data batch: 31/125
# 		Loaded in 4.151213645935059s.
# 		Start processing...
# 		Processed in 391.23087310791016s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0030.nc already generated
# Loading data batch: 32/125
# 		Loaded in 4.3164637088775635s.
# 		Start processing...
# 		Processed in 386.56076192855835s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0031.nc already generated
# Loading data batch: 33/125
# 		Loaded in 4.256587028503418s.
# 		Start processing...
# 		Processed in 397.05133056640625s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0032.nc already generated
# Loading data batch: 34/125
# 		Loaded in 4.6666669845581055s.
# 		Start processing...
# 		Processed in 394.8605728149414s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0033.nc already generated
# Loading data batch: 35/125
# 		Loaded in 4.690323114395142s.
# 		Start processing...
# 		Processed in 396.0733759403229s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0034.nc already generated
# Loading data batch: 36/125
# 		Loaded in 4.703296661376953s.
# 		Start processing...
# 		Processed in 396.0060701370239s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0035.nc already generated
# Loading data batch: 37/125
# 		Loaded in 4.909506797790527s.
# 		Start processing...
# 		Processed in 392.55533051490784s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0036.nc already generated
# Loading data batch: 38/125
# 		Loaded in 4.9438393115997314s.
# 		Start processing...
# 		Processed in 392.4937746524811s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0037.nc already generated
# Loading data batch: 39/125
# 		Loaded in 5.1876747608184814s.
# 		Start processing...
# 		Processed in 389.74682545661926s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0038.nc already generated
# Loading data batch: 40/125
# 		Loaded in 5.24048638343811s.
# 		Start processing...
# 		Processed in 402.72578287124634s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0039.nc already generated
# Loading data batch: 41/125
# 		Loaded in 5.342553615570068s.
# 		Start processing...
# 		Processed in 390.8509039878845s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0040.nc already generated
# Loading data batch: 42/125
# 		Loaded in 5.900188684463501s.
# 		Start processing...
# 		Processed in 399.6486268043518s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0041.nc already generated
# Loading data batch: 43/125
# 		Loaded in 5.783302307128906s.
# 		Start processing...
# 		Processed in 392.67692589759827s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0042.nc already generated
# Loading data batch: 44/125
# 		Loaded in 6.272068977355957s.
# 		Start processing...
# 		Processed in 389.5889847278595s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0043.nc already generated
# Loading data batch: 45/125
# 		Loaded in 6.762451410293579s.
# 		Start processing...
# 		Processed in 393.3461446762085s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0044.nc already generated
# Loading data batch: 46/125
# 		Loaded in 7.440104961395264s.
# 		Start processing...
# 		Processed in 401.5104899406433s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0045.nc already generated
# Loading data batch: 47/125
# 		Loaded in 8.570875644683838s.
# 		Start processing...
# 		Processed in 394.96334648132324s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0046.nc already generated
# Loading data batch: 48/125
# 		Loaded in 11.046107292175293s.
# 		Start processing...
# 		Processed in 393.4453213214874s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0047.nc already generated
# Loading data batch: 49/125
# 		Loaded in 8.781105995178223s.
# 		Start processing...
# 		Processed in 390.60704827308655s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0048.nc already generated
# Loading data batch: 50/125
# 		Loaded in 9.506923198699951s.
# 		Start processing...
# 		Processed in 391.5602807998657s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0049.nc already generated
# Loading data batch: 51/125
# 		Loaded in 9.698074102401733s.
# 		Start processing...
# 		Processed in 393.3956003189087s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0050.nc already generated
# Loading data batch: 52/125
# 		Loaded in 9.866765022277832s.
# 		Start processing...
# 		Processed in 397.92944383621216s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0051.nc already generated
# Loading data batch: 53/125
# 		Loaded in 9.994327306747437s.
# 		Start processing...
# 		Processed in 395.5303065776825s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0052.nc already generated
# Loading data batch: 54/125
# 		Loaded in 10.179035425186157s.
# 		Start processing...
# 		Processed in 390.54353499412537s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0053.nc already generated
# Loading data batch: 55/125
# 		Loaded in 10.58028507232666s.
# 		Start processing...
# 		Processed in 396.09271264076233s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0054.nc already generated
# Loading data batch: 56/125
# 		Loaded in 10.132528305053711s.
# 		Start processing...
# 		Processed in 410.6396942138672s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0055.nc already generated
# Loading data batch: 57/125
# 		Loaded in 10.43682312965393s.
# 		Start processing...
# 		Processed in 409.47994446754456s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0056.nc already generated
# Loading data batch: 58/125
# 		Loaded in 10.462108612060547s.
# 		Start processing...
# 		Processed in 394.36536264419556s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0057.nc already generated
# Loading data batch: 59/125
# 		Loaded in 11.831974744796753s.
# 		Start processing...
# 		Processed in 397.65929913520813s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0058.nc already generated
# Loading data batch: 60/125
# 		Loaded in 11.616552352905273s.
# 		Start processing...
# 		Processed in 398.38285303115845s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0059.nc already generated
# Loading data batch: 61/125
# 		Loaded in 12.055511713027954s.
# 		Start processing...
# 		Processed in 397.06097054481506s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0060.nc already generated
# Loading data batch: 62/125
# 		Loaded in 12.381661415100098s.
# 		Start processing...
# 		Processed in 409.0264732837677s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0061.nc already generated
# Loading data batch: 63/125
# 		Loaded in 11.976199626922607s.
# 		Start processing...
# 		Processed in 391.564151763916s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0062.nc already generated
# Loading data batch: 64/125
# 		Loaded in 12.290385723114014s.
# 		Start processing...
# 		Processed in 393.25558733940125s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0063.nc already generated
# Loading data batch: 65/125
# 		Loaded in 12.374327898025513s.
# 		Start processing...
# 		Processed in 399.78123450279236s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0064.nc already generated
# Loading data batch: 66/125
# 		Loaded in 12.782731533050537s.
# 		Start processing...
# 		Processed in 392.4915246963501s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0065.nc already generated
# Loading data batch: 67/125
# 		Loaded in 12.69809603691101s.
# 		Start processing...
# 		Processed in 396.4090721607208s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0066.nc already generated
# Loading data batch: 68/125
# 		Loaded in 13.288652658462524s.
# 		Start processing...
# 		Processed in 389.5685272216797s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0067.nc already generated
# Loading data batch: 69/125
# 		Loaded in 13.289684295654297s.
# 		Start processing...
# 		Processed in 387.5981249809265s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0068.nc already generated
# Loading data batch: 70/125
# 		Loaded in 14.07815146446228s.
# 		Start processing...
# 		Processed in 387.0747594833374s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0069.nc already generated
# Loading data batch: 71/125
# 		Loaded in 13.557600498199463s.
# 		Start processing...
# 		Processed in 390.95201539993286s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0070.nc already generated
# Loading data batch: 72/125
# 		Loaded in 14.0919771194458s.
# 		Start processing...
# 		Processed in 387.7437822818756s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0071.nc already generated
# Loading data batch: 73/125
# 		Loaded in 14.722400665283203s.
# 		Start processing...
# 		Processed in 387.42248344421387s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0072.nc already generated
# Loading data batch: 74/125
# 		Loaded in 14.496553421020508s.
# 		Start processing...
# 		Processed in 388.6502854824066s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0073.nc already generated
# Loading data batch: 75/125
# 		Loaded in 14.582539558410645s.
# 		Start processing...
# 		Processed in 388.9002962112427s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0074.nc already generated
# Loading data batch: 76/125
# 		Loaded in 14.485579252243042s.
# 		Start processing...
# 		Processed in 386.2262828350067s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0075.nc already generated
# Loading data batch: 77/125
# 		Loaded in 14.977887392044067s.
# 		Start processing...
# 		Processed in 391.673348903656s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0076.nc already generated
# Loading data batch: 78/125
# 		Loaded in 15.243441104888916s.
# 		Start processing...
# 		Processed in 393.1909656524658s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0077.nc already generated
# Loading data batch: 79/125
# 		Loaded in 15.253173828125s.
# 		Start processing...
# 		Processed in 390.1611750125885s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0078.nc already generated
# Loading data batch: 80/125
# 		Loaded in 15.327759981155396s.
# 		Start processing...
# 		Processed in 387.86269426345825s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0079.nc already generated
# Loading data batch: 81/125
# 		Loaded in 15.682576656341553s.
# 		Start processing...
# 		Processed in 386.4924213886261s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0080.nc already generated
# Loading data batch: 82/125
# 		Loaded in 15.830257177352905s.
# 		Start processing...
# 		Processed in 388.10542011260986s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0081.nc already generated
# Loading data batch: 83/125
# 		Loaded in 16.011218786239624s.
# 		Start processing...
# 		Processed in 395.8629219532013s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0082.nc already generated
# Loading data batch: 84/125
# 		Loaded in 16.474260568618774s.
# 		Start processing...
# 		Processed in 389.5067799091339s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0083.nc already generated
# Loading data batch: 85/125
# 		Loaded in 16.672046661376953s.
# 		Start processing...
# 		Processed in 388.93946957588196s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0084.nc already generated
# Loading data batch: 86/125
# 		Loaded in 16.451755046844482s.
# 		Start processing...
# 		Processed in 392.1527638435364s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0085.nc already generated
# Loading data batch: 87/125
# 		Loaded in 16.512794971466064s.
# 		Start processing...
# 		Processed in 387.1950480937958s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0086.nc already generated
# Loading data batch: 88/125
# 		Loaded in 16.634243726730347s.
# 		Start processing...
# 		Processed in 386.85875153541565s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0087.nc already generated
# Loading data batch: 89/125
# 		Loaded in 17.237600803375244s.
# 		Start processing...
# 		Processed in 387.96696949005127s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0088.nc already generated
# Loading data batch: 90/125
# 		Loaded in 17.162636518478394s.
# 		Start processing...
# 		Processed in 389.67497873306274s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0089.nc already generated
# Loading data batch: 91/125
# 		Loaded in 17.596001625061035s.
# 		Start processing...
# 		Processed in 399.4064242839813s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0090.nc already generated
# Loading data batch: 92/125
# 		Loaded in 17.821133613586426s.
# 		Start processing...
# 		Processed in 386.39572620391846s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0091.nc already generated
# Loading data batch: 93/125
# 		Loaded in 17.629909992218018s.
# 		Start processing...
# 		Processed in 391.34228324890137s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0092.nc already generated
# Loading data batch: 94/125
# 		Loaded in 17.85038471221924s.
# 		Start processing...
# 		Processed in 390.02087450027466s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0093.nc already generated
# Loading data batch: 95/125
# 		Loaded in 18.33256697654724s.
# 		Start processing...
# 		Processed in 387.2620141506195s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0094.nc already generated
# Loading data batch: 96/125
# 		Loaded in 18.39644432067871s.
# 		Start processing...
# 		Processed in 385.6074855327606s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0095.nc already generated
# Loading data batch: 97/125
# 		Loaded in 18.54769468307495s.
# 		Start processing...
# 		Processed in 388.71801137924194s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0096.nc already generated
# Loading data batch: 98/125
# 		Loaded in 18.587160110473633s.
# 		Start processing...
# 		Processed in 386.1445186138153s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0097.nc already generated
# Loading data batch: 99/125
# 		Loaded in 18.960009336471558s.
# 		Start processing...
# 		Processed in 388.3819317817688s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0098.nc already generated
# Loading data batch: 100/125
# 		Loaded in 18.75084686279297s.
# 		Start processing...
# 		Processed in 389.2390172481537s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0099.nc already generated
# Loading data batch: 101/125
# 		Loaded in 18.952550172805786s.
# 		Start processing...
# 		Processed in 388.0719063282013s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0100.nc already generated
# Loading data batch: 102/125
# 		Loaded in 19.087090253829956s.
# 		Start processing...
# 		Processed in 389.139999628067s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0101.nc already generated
# Loading data batch: 103/125
# 		Loaded in 19.595667839050293s.
# 		Start processing...
# 		Processed in 388.0736129283905s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0102.nc already generated
# Loading data batch: 104/125
# 		Loaded in 19.775749683380127s.
# 		Start processing...
# 		Processed in 391.3446362018585s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0103.nc already generated
# Loading data batch: 105/125
# 		Loaded in 20.02826189994812s.
# 		Start processing...
# 		Processed in 387.94389510154724s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0104.nc already generated
# Loading data batch: 106/125
# 		Loaded in 19.971863269805908s.
# 		Start processing...
# 		Processed in 386.1076760292053s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0105.nc already generated
# Loading data batch: 107/125
# 		Loaded in 19.915186882019043s.
# 		Start processing...
# 		Processed in 387.1735701560974s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0106.nc already generated
# Loading data batch: 108/125
# 		Loaded in 20.29828929901123s.
# 		Start processing...
# 		Processed in 388.00629234313965s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0107.nc already generated
# Loading data batch: 109/125
# 		Loaded in 20.51489233970642s.
# 		Start processing...
# 		Processed in 388.64324045181274s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0108.nc already generated
# Loading data batch: 110/125
# 		Loaded in 20.86230707168579s.
# 		Start processing...
# 		Processed in 389.2913267612457s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0109.nc already generated
# Loading data batch: 111/125
# 		Loaded in 20.931071281433105s.
# 		Start processing...
# 		Processed in 391.4516108036041s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0110.nc already generated
# Loading data batch: 112/125
# 		Loaded in 21.080190896987915s.
# 		Start processing...
# 		Processed in 389.0181791782379s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0111.nc already generated
# Loading data batch: 113/125
# 		Loaded in 21.271490335464478s.
# 		Start processing...
# 		Processed in 390.12158966064453s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0112.nc already generated
# Loading data batch: 114/125
# 		Loaded in 21.393523931503296s.
# 		Start processing...
# 		Processed in 387.21619176864624s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0113.nc already generated
# Loading data batch: 115/125
# 		Loaded in 21.376522302627563s.
# 		Start processing...
# 		Processed in 389.0970194339752s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0114.nc already generated
# Loading data batch: 116/125
# 		Loaded in 21.693338632583618s.
# 		Start processing...
# 		Processed in 389.9122314453125s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0115.nc already generated
# Loading data batch: 117/125
# 		Loaded in 21.765292167663574s.
# 		Start processing...
# 		Processed in 387.9011194705963s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0116.nc already generated
# Loading data batch: 118/125
# 		Loaded in 22.85734272003174s.
# 		Start processing...
# 		Processed in 396.606240272522s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0117.nc already generated
# Loading data batch: 119/125
# 		Loaded in 22.63021159172058s.
# 		Start processing...
# 		Processed in 388.19361186027527s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0118.nc already generated
# Loading data batch: 120/125
# 		Loaded in 23.430444478988647s.
# 		Start processing...
# 		Processed in 389.71727752685547s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0119.nc already generated
# Loading data batch: 121/125
# 		Loaded in 23.04690933227539s.
# 		Start processing...
# 		Processed in 392.6442708969116s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0120.nc already generated
# Loading data batch: 122/125
# 		Loaded in 22.765703439712524s.
# 		Start processing...
# 		Processed in 386.9313449859619s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0121.nc already generated
# Loading data batch: 123/125
# 		Loaded in 23.23670482635498s.
# 		Start processing...
# 		Processed in 391.34206891059875s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0122.nc already generated
# Loading data batch: 124/125
# 		Loaded in 23.027323007583618s.
# 		Start processing...
# 		Processed in 386.5804204940796s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0123.nc already generated
# Loading data batch: 125/125
# 		Loaded in 23.654033660888672s.
# 		Start processing...
# 		Processed in 386.6801838874817s
# /home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0124.nc already generated

# %%
file_name
# Out:
# '/home/hawbecker/kaggle/LEAP/processed_data/test_data_X_0001.nc'
